# %%
import numpy as np
import csv
import pandas as pd
import os
import re
import string as st

# %%
# Function to remove @names and special character
def punc_clean(text):
    
    text= ' '.join(re.sub("(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)" , " ", text).split())
    
    return text

def preprocess(path):
    path = os.path.join(path)
    data = pd.read_csv(path)
    
    data['text'] = data['text'].apply(punc_clean)
    data['creation_date_time'] = data['creation_date_time'].apply(lambda x: x[:10])
    data["location"].fillna("No Location", inplace = True)
    
    return data

# %%
pfizer_data = preprocess("latest_data/Pfizer.csv")
pfizer_data
# Out:
#                  tweet_id              user_id         username  \
# 0     1502972060200574980  1241174508293312513  AngelaC11111101
# 1     1502972032375754757             54516759        gladeolie
# 2     1502972013647994880            156451829        ctramseur
# 3     1502972010892255235  1009545566290837504   SystemLordMoot
# 4     1502971982673027075  1144167004892467200         DMB12445
# ...                   ...                  ...              ...
# 4339  1502792330348216325  1431762585519595520  WaitingForPerot
# 4340  1502792313021423616           3267880214          govtflu
# 4341  1502792277277790212  1456321142453673984        Tshepp_90
# 4342  1502792251721846786  1233974172696686593       Latifa2390
# 4343  1502792197443313668  1356015027862401024    SenseReceptor
#
#                                                    text  like_count  \
# 0                            The start was given Wait..           0
# ...

# %%
# Convert it to CSV
pfizer_data.to_csv("pfizer.csv", encoding='utf-8', index=False)

# %%
covaxin_data = preprocess("latest_data/Covaxin.csv")
covaxin_data
# Out:
#                  tweet_id              user_id         username  \
# 0     1502900173445296136            489184831           chovue
# 1     1502899182910119937  1389478820676210688        india_vac
# 2     1502897767315767298  1396115471703805953      CovidvaxDEL
# 3     1502897042334519301            489184831           chovue
# 4     1502896817314607107           3259025400      CaptainXemo
# ...                   ...                  ...              ...
# 2307  1500404994268303361  1244878602094530560  Rajnees59765724
# 2308  1500403416719593472  1406895607680102404           vaxblr
# 2309  1500401792856768512  1389478820676210688        india_vac
# 2310  1500396670374219779           4806490885         abyisnow
# 2311  1500395799418589186   868380317039591425  Mayank_P_Grover
#
#                                                    text  like_count  \
# 0     sigh. youre the one in the dark If you truly d...           0
# ...

# %%
# Convert it to CSV
covaxin_data.to_csv("Covaxin.csv", encoding='utf-8', index=False)

# %%
moderna_data = preprocess("latest_data/Moderna.csv")
moderna_data
# Out:
#                  tweet_id              user_id        username  \
# 0     1502933227991822338   954212951497564160     TimmyTate66
# 1     1502933156655435777  1320331014124695552       TheosTina
# 2     1502933102498181122  1466683352505749507  thetruthb3t0ld
# 3     1502932998215417856             26347653  AutomaticEarth
# 4     1502932679066624001   933450200361947136   MoveOverThere
# ...                   ...                  ...             ...
# 2186  1502419212844744707             24195285          reinoe
# 2187  1502419180129337349  1463342010463494152  StockPlungeBot
# 2188  1502419129361264640  1439398920732307456   LeighDrummond
# 2189  1502419018581479428  1102671699424825344         rubic3n
# 2190  1502418485489463297            184153867     Hey_Hey_Joe
#
#                                                    text  like_count  \
# 0     Double vaxxed w Pfizer and boosted Moderna No ...           0
# 1     Moderna tried for 10 years to make mRNA techno...           0
# ...

# %%
# Convert it to CSV
moderna_data.to_csv("Moderna.csv", encoding='utf-8', index=False)

# %%
sinovac_data = preprocess("latest_data/Sinovac.csv")
sinovac_data
# Out:
#                 tweet_id              user_id         username  \
# 0    1502959853635239940             84204994    mackattackone
# 1    1502958946377740288   697443656706453504       RockTrolla
# 2    1502954945712033792  1231486724087222272      Transit_Jam
# 3    1502953689643986944   742763463597031424        AFranzsen
# 4    1502951039183556609   969429491855618048        KCMO_Neal
# ..                   ...                  ...              ...
# 906  1500446344443400193  1377836392902889472          foxosk1
# 907  1500440744233877504  1377836392902889472          foxosk1
# 908  1500439703786606597            462111175          Tonko35
# 909  1500438679029833729   975566592720306177  pharmaniaga_bhd
# 910  1500438515515277314           2238916212      WORLDOFBUZZ
#
#                                                   text  like_count  \
# 0    Then why is there an overwhelming sinovac upta...           0
# 1                         Only 50 sinovac Is it Right?           0
# ...

# %%
# Convert it to CSV
sinovac_data.to_csv("Sinovac.csv", encoding='utf-8', index=False)

# %%
sputnik_data = preprocess("latest_data/Sputnik.csv")
sputnik_data
# Out:
#                 tweet_id              user_id         username  \
# 0    1502885637086609411  1455052349228023814      AndrewTRei1
# 1    1502873976716107776  1498608701653102594   hamzaouihazim0
# 2    1502854289064173580            269110574         PolStuff
# 3    1502846122129334276  1199410182230548480         cealaigi
# 4    1502845215161602050  1502842093592580103   chicken_mcnug_
# ..                   ...                  ...              ...
# 451  1500375433665257476   961331673152487426  Anymous84861064
# 452  1500374067903275008             60444865  KittyOwner_Club
# 453  1500373492952612864  1334654385863811072       MasaruTogo
# 454  1500372873948499978             34262462       SputnikInt
# 455  1500367094235340801   878273096079335425         mariajt_
#
#                                                   text  like_count  \
# 0    I will correctly remind people yet again that ...           2
# 1        Local businessman first to take Sputnik V jab           0
# ...

# %%
# Convert it to CSV
sputnik_data.to_csv("Sputnik.csv", encoding='utf-8', index=False)
